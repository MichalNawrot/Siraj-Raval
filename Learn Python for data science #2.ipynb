# %%
import tweepy
from textblob import TextBlob
import csv
import re 
    
# Step 1 - Authenticate
consumer_key= 'hbxj0Bi8A6LZgGFGWjKXJkwxF'
consumer_secret= 'oH2hUfR1zBGwuCUNd9oeRgVqTOwHoEXKoEcFJyqRHuYjI3riwH'

access_token='920524304827277312-0nviufoDvMlgDR5Gb8NMZ8AFBw2oxoU'
access_token_secret='vAQH4zgqTOyQiFtmLhmVuYJGgokxxQnMRekcjquGx05BT'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

#Step 3 - Retrieve Tweets
public_tweets = api.search('BCG', lang='en', count=100)



#CHALLENGE - Instead of printing out each tweet, save each Tweet to a CSV file
#and label each one as either 'positive' or 'negative', depending on the sentiment 
#You can decide the sentiment polarity threshold yourself

def clean_tweet(tweet):
    return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet).split())

def get_tweet_sentiment(tweet):
    analysis = TextBlob(clean_tweet(tweet))
    #analysis = TextBlob(tweet)
    if analysis.sentiment.polarity > 0:
        return 'positive'
    elif analysis.sentiment.polarity == 0:
        return 'neutral'
    else:
        return 'negative'

with open('tweets2.csv', 'w', newline='') as csvfile:
    writerFile = csv.writer(csvfile)
    for tweet in public_tweets:
        if 'RT @' not in tweet.text:
            print(tweet.text)
            print(get_tweet_sentiment(tweet.text))
            print('\n')
            analysis = TextBlob(tweet.text)
            writerFile.writerow([clean_tweet(tweet.text)] + [get_tweet_sentiment(tweet.text)])
            #writerFile.writerow([tweet.text.encode('utf-8')]+[get_tweet_sentiment(tweet.text)])
        else:
            nothing = 1

    
    #Step 4 Perform Sentiment Analysis on Tweets
    
    #print(analysis.sentiment)
    #if analysis.sentiment.polarity >= 0:
    #    print('pos')
    #else:
    #   print('neg')
    #print('\n')
print("")
# Out:
# What Digital Champions Do Differently https://t.co/1vuZisXpLg
# #Digital #Infographic https://t.co/m8d6z4NLaA
# neutral
#
#
# Cómo enseñamos: Blockchain will change the way we do business https://t.co/yqIGPb0T9q What is it? https://t.co/pKJY9MvhDc #inglés #Madrid
# neutral
#
#
# how can we use #Blockchain in #music to cut out the middleman https://t.co/WhNbJJYHTP
# neutral
#
#
# Ya gotta know where I came from to understand how I already be knowing shit.... #TrenchVet #BCG #100K #SW #KDM #SG 💰💯🤐
# negative
#
#
# Hold $BTC until $BCG or just buy they alts now?
# #FLICKER Wade Davis SUns #CNNDebateNight #QueenSugar Curtis Granderson #STAR Chivas Utley
# neutral
#
#
# @BCGcareers @BCG I need this one toooooooooo
# neutral
#
#
# 7.5in AR Upper SBR Pistol 5.56 w/BCG Custom NF : Rifle Barrels at https://t.co/iQPpTzVqgN https://t.co/H5fIMXuilz https://t.co/QOiOseHyh9
# neutral
#
#
# ...
